# %%
import os
from pathlib import Path
import subprocess
import time
from libs import capture as cptr
import os
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt
import numpy as np

# %%
# Directorio raíz desde donde comenzar la búsqueda
directorio_raiz = "./D205AAA/Tacho"

# Patrón para buscar directorios
patron_directorio = "pulse_"    
patron_archivos = "g__"

# Recorrer los directorios y subdirectorios
elementos = os.listdir(directorio_raiz)
# Verificar si algún directorio coincide con el patrón
directorios_pulse = [d for d in elementos if d.startswith(patron_directorio)]

for dir in directorios_pulse:
    print(dir)
    ruta_directorio = os.path.join(directorio_raiz, dir)

    archivos = os.listdir(ruta_directorio)
    archivos_g = [d for d in archivos if d.startswith(patron_archivos)]
    
    suma = np.zeros(100000)
    for archivo in archivos_g:
        ruta_archivo = os.path.join(ruta_directorio, archivo)
        #print(archivo)
        fs, audio_data = wav.read(ruta_archivo)


        indice = np.argmax(audio_data < -0.1)

        audio_data2 = audio_data[indice:indice+100000]

        if  (len(audio_data2) >= 100000):

            suma = suma + audio_data2

        #print(indice)

        duracion = len(audio_data2) / fs
        tiempo =  380 / 2 * duracion * (1.0 / len(audio_data2)) * np.arange(len(audio_data2))

        plt.plot( tiempo,audio_data2)

    #ruta_chirp = os.path.join(ruta_directorio, "chirp.wav")
        
    #fs, chirp_data = wav.read(ruta_chirp)

    #correlate = np.correlate(suma,chirp_data,mode="same")


    plt.plot(tiempo, suma)
    #plt.plot(tiempo, correlate)
    plt.xlabel('Tiempo (s)')
    plt.ylabel('Amplitud')
    plt.title(dir)
    plt.grid(True)
    plt.show()
# Out:
# pulse_10_60_10
# pulse_110_120_2
# pulse_110_121_2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 49
#      40     plt.plot( tiempo,audio_data2)
#      42 #ruta_chirp = os.path.join(ruta_directorio, "chirp.wav")
#      43
#      44 #fs, chirp_data = wav.read(ruta_chirp)
#      45
#      46 #correlate = np.correlate(suma,chirp_data,mode="same")
# ---> 49 plt.plot(tiempo, suma)
#      50 #plt.plot(tiempo, correlate)
#      51 plt.xlabel('Tiempo (s)')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (98030,) and (100000,)
